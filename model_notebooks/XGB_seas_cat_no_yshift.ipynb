# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

import warnings
import data_func.read_data as read_data
warnings.filterwarnings("ignore", category=FutureWarning, module="xgboost")
warnings.filterwarnings("ignore", category=FutureWarning, message="is_sparse is deprecated")

# %% [markdown]
# # Load datasets

# %%
dataframes = read_data.get_training_data()
X_frames_train = dataframes[0]
Y_frames_train = dataframes[1]
X_frames_test = read_data.get_test_data()

# %%
XTRA = X_frames_train[0]
XTRB = X_frames_train[1]
XTRC = X_frames_train[2]

YA = Y_frames_train[0]
YB = Y_frames_train[1]
YC = Y_frames_train[2]

# %% [markdown]
# Need to reset index for aggregation function

# %%
import data_func.aggregation as data_agg

# %% [markdown]
# drop 0 since we want to match on the "whole" hour.

# %%
for i in range(len(X_frames_test)):
    X_frames_test[i] = X_frames_test[i].drop(columns=["date_calc"])

# %% [markdown]
# # Data clean up

# %%
# making shure that target values line up with x_values
import data_func.aggregation as data_agg

categorical_col = ['dew_or_rime:idx', 'precip_type_5min:idx']

def aggregate_correct_x(x: pd.DataFrame) -> pd.DataFrame:
   categorical = x[["date_forecast"] + categorical_col]
   mean = x.drop(columns=categorical_col)

   categorical = data_agg.gen_agg(categorical, data_agg.stocastic_median)
   mean = data_agg.gen_agg(mean, "mean")

   return pd.merge(categorical, mean, on="date_forecast")

def data_allign(x_train, y_train):

  y_train.dropna(inplace=True)
  x_train = aggregate_correct_x(x_train)
  combined_data = pd.merge(x_train, y_train, left_on='date_forecast', right_on='time')
  y_train = combined_data['pv_measurement']

  if 'time' and 'pv_measurement' in combined_data.columns:
    combined_data.drop(columns=['time', 'pv_measurement'], inplace=True)
    
  return combined_data, y_train



X_train = [XTRA, XTRB, XTRC]
Y_train = [YA, YB, YC]

for i in range(len(X_train)):
    X_train[i], Y_train[i] = data_allign(X_train[i], Y_train[i])

for j in range(len(X_frames_test)):
    X_frames_test[j] = aggregate_correct_x(X_frames_test[j])

# %%
#Verify length matches
for x in range(len(X_train)):
    print("x,y: ", len(X_train[x]), len(Y_train[x]))
# Out:
# x,y:  0 0
# x,y:  0 0
# x,y:  0 0

# %% [markdown]
# # Feature engineering

# %%
import data_func.timeseasonality as DTS
import data_func.one_hot_encoding as OHE
for i in range(len(X_train)):
    X_train[i] = DTS.append_seasonal_columns(X_train[i])
    X_train[i].drop(columns=['date_forecast'], inplace=True)

for i in range(len(X_frames_test)):
    X_frames_test[i] = DTS.append_seasonal_columns(X_frames_test[i])
    X_frames_test[i].drop(columns=['date_forecast'], inplace=True)

# THIS SECTION CAN ONLY WORK IF THE PREVIOUS AGGREGATION IS DONE INDIVIDUALLY FOR CATEGORICAL DATA
# import data_func.one_hot_encoding as OHE

# for i in range(len(X_train)):
#      X_train[i] = OHE.one_hot_encode(X_train[i], ['dew_or_rime:idx', 'precip_type_5min:idx'])

# for i in range(len(X_frames_test)):
#      X_frames_test[i] = OHE.one_hot_encode(X_frames_test[i], ['dew_or_rime:idx', 'precip_type_5min:idx'])
#      X_frames_test[i]["dew_or_rime:idx_-1"] = 0 
#      X_frames_test[i]["precip_type_5min:idx_2"] = 0 
#      X_frames_test[i]["precip_type_5min:idx_3"] = 0

# %%
X_train[0].describe().transpose()
# Out:
#                                 count  mean  std  min  25%  50%  75%  max
# dew_or_rime:idx                   0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# precip_type_5min:idx              0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# absolute_humidity_2m:gm3          0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# air_density_2m:kgm3               0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ceiling_height_agl:m              0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# clear_sky_energy_1h:J             0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# clear_sky_rad:W                   0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# cloud_base_agl:m                  0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# dew_point_2m:K                    0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# diffuse_rad:W                     0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# diffuse_rad_1h:J                  0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# direct_rad:W                      0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# direct_rad_1h:J                   0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# effective_cloud_cover:p           0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# elevation:m                       0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# fresh_snow_12h:cm                 0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# fresh_snow_1h:cm                  0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# fresh_snow_24h:cm                 0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# fresh_snow_3h:cm                  0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# fresh_snow_6h:cm                  0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# is_day:idx                        0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# is_in_shadow:idx                  0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# msl_pressure:hPa                  0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# precip_5min:mm                    0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# pressure_100m:hPa                 0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# pressure_50m:hPa                  0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# prob_rime:p                       0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# rain_water:kgm2                   0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# relative_humidity_1000hPa:p       0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# sfc_pressure:hPa                  0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# snow_density:kgm3                 0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# snow_depth:cm                     0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# snow_drift:idx                    0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# snow_melt_10min:mm                0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# snow_water:kgm2                   0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# sun_azimuth:d                     0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# sun_elevation:d                   0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# super_cooled_liquid_water:kgm2    0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# t_1000hPa:K                       0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# total_cloud_cover:p               0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# visibility:m                      0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# wind_speed_10m:ms                 0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# wind_speed_u_10m:ms               0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# wind_speed_v_10m:ms               0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# wind_speed_w_1000hPa:ms           0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# sinus_day                         0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# cosinus_day                       0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# sinus_year                        0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# cosinus_year                      0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN

# %%
X_frames_test[0].describe().transpose()
# Out:
#                                 count          mean           std  \
# dew_or_rime:idx                 720.0  2.916667e-02  1.683905e-01
# precip_type_5min:idx            720.0  6.388889e-02  2.447249e-01
# absolute_humidity_2m:gm3        720.0  8.205903e+00  2.178425e+00
# air_density_2m:kgm3             720.0  1.233150e+00  3.210283e-02
# ceiling_height_agl:m            532.0  3.096333e+03  2.945732e+03
# clear_sky_energy_1h:J           720.0  1.227651e+06  1.101479e+06
# clear_sky_rad:W                 720.0  3.410140e+02  3.069119e+02
# cloud_base_agl:m                650.0  1.891609e+03  2.128155e+03
# dew_point_2m:K                  720.0  2.808002e+02  4.339592e+00
# diffuse_rad:W                   720.0  8.490232e+01  7.859020e+01
# diffuse_rad_1h:J                720.0  3.056483e+05  2.783206e+05
# direct_rad:W                    720.0  1.147817e+02  1.721850e+02
# direct_rad_1h:J                 720.0  4.132130e+05  6.121724e+05
# effective_cloud_cover:p         720.0  6.413229e+01  3.736935e+01
# elevation:m                     720.0  6.000000e+00  0.000000e+00
# fresh_snow_12h:cm               720.0  3.472222e-04  6.583496e-03
# fresh_snow_1h:cm                720.0  1.736111e-04  4.658475e-03
# fresh_snow_24h:cm               720.0  3.472222e-04  6.583496e-03
# fresh_snow_3h:cm                720.0  3.472222e-04  6.583496e-03
# fresh_snow_6h:cm                720.0  3.472222e-04  6.583496e-03
# is_day:idx                      720.0  7.937500e-01  3.855381e-01
# is_in_shadow:idx                720.0  2.253472e-01  4.053277e-01
# msl_pressure:hPa                720.0  1.016797e+03  9.731263e+00
# precip_5min:mm                  720.0  7.475695e-03  3.133489e-02
# pressure_100m:hPa               720.0  1.003811e+03  9.620932e+00
# pressure_50m:hPa                720.0  1.009853e+03  9.717662e+00
# prob_rime:p                     720.0  0.000000e+00  0.000000e+00
# rain_water:kgm2                 720.0  1.333333e-02  5.235418e-02
# relative_humidity_1000hPa:p     720.0  7.075007e+01  1.553147e+01
# sfc_pressure:hPa                720.0  1.015921e+03  9.817863e+00
# snow_density:kgm3                 0.0           NaN           NaN
# snow_depth:cm                   720.0  0.000000e+00  0.000000e+00
# snow_drift:idx                  720.0  0.000000e+00  0.000000e+00
# snow_melt_10min:mm              720.0  0.000000e+00  0.000000e+00
# snow_water:kgm2                 720.0  6.114583e-02  2.017480e-01
# sun_azimuth:d                   720.0  1.791814e+02  1.039713e+02
# sun_elevation:d                 720.0  2.029444e+01  1.863013e+01
# super_cooled_liquid_water:kgm2  720.0  6.392361e-02  1.087915e-01
# t_1000hPa:K                     720.0  2.847234e+02  5.811303e+00
# total_cloud_cover:p             720.0  6.930979e+01  3.767553e+01
# visibility:m                    720.0  3.359962e+04  1.561533e+04
# wind_speed_10m:ms               720.0  3.075139e+00  1.795147e+00
# wind_speed_u_10m:ms             720.0  1.739271e+00  2.714267e+00
# wind_speed_v_10m:ms             720.0 -2.189931e-01  1.488172e+00
# wind_speed_w_1000hPa:ms         720.0  0.000000e+00  0.000000e+00
# sinus_day                       720.0  2.218596e-14  7.075983e-01
# cosinus_day                     720.0 -4.169443e-14  7.075983e-01
# sinus_year                      720.0  4.219918e-01  2.542895e-01
# cosinus_year                    720.0 -8.600671e-01  1.328861e-01
#
#                                         min           25%           50%  \
# dew_or_rime:idx                    0.000000      0.000000  0.000000e+00
# precip_type_5min:idx               0.000000      0.000000  0.000000e+00
# absolute_humidity_2m:gm3           3.200000      6.693750  8.050000e+00
# air_density_2m:kgm3                1.151000      1.209000  1.238625e+00
# ceiling_height_agl:m              53.299999    953.000000  1.712700e+03
# clear_sky_energy_1h:J              0.000000  48799.869141  9.337900e+05
# clear_sky_rad:W                    0.000000     17.950000  2.995750e+02
# cloud_base_agl:m                  30.225000    509.556274  1.035875e+03
# dew_point_2m:K                   268.100006    278.024994  2.810500e+02
# diffuse_rad:W                      0.000000      8.087500  7.530000e+01
# diffuse_rad_1h:J                   0.000000  34182.730469  2.656778e+05
# direct_rad:W                       0.000000      0.025000  1.395000e+01
# direct_rad_1h:J                    0.000000    714.418762  6.590085e+04
# effective_cloud_cover:p            0.000000     32.675001  7.687500e+01
# elevation:m                        6.000000      6.000000  6.000000e+00
# fresh_snow_12h:cm                  0.000000      0.000000  0.000000e+00
# fresh_snow_1h:cm                   0.000000      0.000000  0.000000e+00
# fresh_snow_24h:cm                  0.000000      0.000000  0.000000e+00
# fresh_snow_3h:cm                   0.000000      0.000000  0.000000e+00
# fresh_snow_6h:cm                   0.000000      0.000000  0.000000e+00
# is_day:idx                         0.000000      1.000000  1.000000e+00
# is_in_shadow:idx                   0.000000      0.000000  0.000000e+00
# msl_pressure:hPa                 986.025024   1011.549988  1.020438e+03
# precip_5min:mm                     0.000000      0.000000  0.000000e+00
# pressure_100m:hPa                973.799988    998.418747  1.007475e+03
# pressure_50m:hPa                 979.625000   1004.437515  1.013562e+03
# prob_rime:p                        0.000000      0.000000  0.000000e+00
# rain_water:kgm2                    0.000000      0.000000  0.000000e+00
# relative_humidity_1000hPa:p       24.824999     60.368752  7.355000e+01
# sfc_pressure:hPa                 985.450012   1010.487503  1.019663e+03
# snow_density:kgm3                       NaN           NaN           NaN
# snow_depth:cm                      0.000000      0.000000  0.000000e+00
# snow_drift:idx                     0.000000      0.000000  0.000000e+00
# snow_melt_10min:mm                 0.000000      0.000000  0.000000e+00
# snow_water:kgm2                    0.000000      0.000000  0.000000e+00
# sun_azimuth:d                     13.441751     89.981750  1.809610e+02
# sun_elevation:d                  -11.534750      2.447438  1.980063e+01
# super_cooled_liquid_water:kgm2     0.000000      0.000000  0.000000e+00
# t_1000hPa:K                      273.799988    279.849976  2.847750e+02
# total_cloud_cover:p                0.000000     38.918751  9.162500e+01
# visibility:m                    2104.725098  19721.299805  3.675865e+04
# wind_speed_10m:ms                  0.100000      1.593750  2.950000e+00
# wind_speed_u_10m:ms               -4.275000     -0.300000  1.737500e+00
# wind_speed_v_10m:ms               -4.300000     -1.300000 -3.000000e-01
# wind_speed_w_1000hPa:ms            0.000000      0.000000  0.000000e+00
# sinus_day                         -0.997859     -0.682469  7.872869e-14
# cosinus_day                       -0.997859     -0.682469 -7.872869e-14
# sinus_year                        -0.026074      0.221336  4.703156e-01
# cosinus_year                      -1.000000     -0.975197 -8.824982e-01
#
#                                          75%           max
# dew_or_rime:idx                 0.000000e+00  1.000000e+00
# precip_type_5min:idx            0.000000e+00  1.000000e+00
# absolute_humidity_2m:gm3        9.981250e+00  1.367500e+01
# air_density_2m:kgm3             1.260000e+00  1.299750e+00
# ceiling_height_agl:m            4.097362e+03  1.143078e+04
# clear_sky_energy_1h:J           2.276145e+06  2.987530e+06
# clear_sky_rad:W                 6.617375e+02  8.349500e+02
# cloud_base_agl:m                2.437175e+03  1.125670e+04
# dew_point_2m:K                  2.843812e+02  2.895500e+02
# diffuse_rad:W                   1.342313e+02  3.075000e+02
# diffuse_rad_1h:J                4.891316e+05  1.098738e+06
# direct_rad:W                    1.847312e+02  6.678000e+02
# direct_rad_1h:J                 6.564714e+05  2.388906e+06
# effective_cloud_cover:p         9.995000e+01  1.000000e+02
# elevation:m                     6.000000e+00  6.000000e+00
# fresh_snow_12h:cm               0.000000e+00  1.250000e-01
# fresh_snow_1h:cm                0.000000e+00  1.250000e-01
# fresh_snow_24h:cm               0.000000e+00  1.250000e-01
# fresh_snow_3h:cm                0.000000e+00  1.250000e-01
# fresh_snow_6h:cm                0.000000e+00  1.250000e-01
# is_day:idx                      1.000000e+00  1.000000e+00
# is_in_shadow:idx                0.000000e+00  1.000000e+00
# msl_pressure:hPa                1.023850e+03  1.029500e+03
# precip_5min:mm                  0.000000e+00  2.875000e-01
# pressure_100m:hPa               1.010925e+03  1.016325e+03
# pressure_50m:hPa                1.017000e+03  1.022500e+03
# prob_rime:p                     0.000000e+00  0.000000e+00
# rain_water:kgm2                 0.000000e+00  5.250000e-01
# relative_humidity_1000hPa:p     8.327500e+01  9.700000e+01
# sfc_pressure:hPa                1.023031e+03  1.028700e+03
# snow_density:kgm3                        NaN           NaN
# snow_depth:cm                   0.000000e+00  0.000000e+00
# snow_drift:idx                  0.000000e+00  0.000000e+00
# snow_melt_10min:mm              0.000000e+00  0.000000e+00
# snow_water:kgm2                 0.000000e+00  2.900000e+00
# sun_azimuth:d                   2.712448e+02  3.481185e+02
# sun_elevation:d                 3.886181e+01  4.990350e+01
# super_cooled_liquid_water:kgm2  1.000000e-01  6.000000e-01
# t_1000hPa:K                     2.881750e+02  3.019500e+02
# total_cloud_cover:p             1.000000e+02  1.000000e+02
# visibility:m                    4.609694e+04  6.386823e+04
# wind_speed_10m:ms               4.206250e+00  9.075000e+00
# wind_speed_u_10m:ms             3.750000e+00  9.050000e+00
# wind_speed_v_10m:ms             7.312500e-01  3.800000e+00
# wind_speed_w_1000hPa:ms         0.000000e+00  0.000000e+00
# sinus_day                       6.824693e-01  9.978589e-01
# cosinus_day                     6.824693e-01  9.978589e-01
# sinus_year                      6.344533e-01  8.792019e-01
# cosinus_year                   -7.729611e-01 -4.764495e-01

# %% [markdown]
# # Training the model

# %%
x_train_a, x_val_a, y_train_a, y_val_a = train_test_split(X_train[0], Y_train[0], test_size=0.17, random_state=None)
x_train_b, x_val_b, y_train_b, y_val_b = train_test_split(X_train[1], Y_train[1], test_size=0.17, random_state=None)
x_train_c, x_val_c, y_train_c, y_val_c = train_test_split(X_train[2], Y_train[2], test_size=0.17, random_state=None)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/peterlawrence/Repos/TDT4173-ML/model_notebooks/XGB_seas_cat_yshift.ipynb Cell 18 line 1
# ----> <a href='vscode-notebook-cell:/Users/peterlawrence/Repos/TDT4173-ML/model_notebooks/XGB_seas_cat_yshift.ipynb#X45sZmlsZQ%3D%3D?line=0'>1</a> x_train_a, x_val_a, y_train_a, y_val_a = train_test_split(X_train[0], Y_train[0], test_size=0.17, random_state=None)
#       <a href='vscode-notebook-cell:/Users/peterlawrence/Repos/TDT4173-ML/model_notebooks/XGB_seas_cat_yshift.ipynb#X45sZmlsZQ%3D%3D?line=1'>2</a> x_train_b, x_val_b, y_train_b, y_val_b = train_test_split(X_train[1], Y_train[1], test_size=0.17, random_state=None)
#       <a href='vscode-notebook-cell:/Users/peterlawrence/Repos/TDT4173-ML/model_notebooks/XGB_seas_cat_yshift.ipynb#X45sZmlsZQ%3D%3D?line=2'>3</a> x_train_c, x_val_c, y_train_c, y_val_c = train_test_split(X_train[2], Y_train[2], test_size=0.17, random_state=None)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/utils/_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
#     213     # When the function is just a wrapper around an estimator, we allow
#     214     # the function to delegate validation to the estimator, but we replace
#     215     # the name of the estimator by the name of the function in the error
#     216     # message to avoid confusion.
#     217     msg = re.sub(
#     218         r"parameter of \w+ must be",
#     219         f"parameter of {func.__qualname__} must be",
#     220         str(e),
#     221     )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_split.py:2617, in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2614 arrays = indexable(*arrays)
#    2616 n_samples = _num_samples(arrays[0])
# -> 2617 n_train, n_test = _validate_shuffle_split(
#    2618     n_samples, test_size, train_size, default_test_size=0.25
#    2619 )
#    2621 if shuffle is False:
#    2622     if stratify is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_split.py:2273, in _validate_shuffle_split(n_samples, test_size, train_size, default_test_size)
#    2270 n_train, n_test = int(n_train), int(n_test)
#    2272 if n_train == 0:
# -> 2273     raise ValueError(
#    2274         "With n_samples={}, test_size={} and train_size={}, the "
#    2275         "resulting train set will be empty. Adjust any of the "
#    2276         "aforementioned parameters.".format(n_samples, test_size, train_size)
#    2277     )
#    2279 return n_train, n_test
#
# ValueError: With n_samples=0, test_size=0.17 and train_size=None, the resulting train set will be empty. Adjust any of the aforementioned parameters.

# %%
# Use params from hyperparameter tuning using optuna
params_a = {'random_state': 42, 'n_estimators': 980, 'max_depth': 9, 'learning_rate': 0.029035565559484028, 'subsample': 0.8393121619033767, 'colsample_bytree': 0.7589542758688459}
params_b = {'random_state': 42, 'n_estimators': 955, 'max_depth': 9, 'learning_rate': 0.02949625834198986, 'subsample': 0.8030196155828968, 'colsample_bytree': 0.72518389089994}
params_c = {'random_state': 42, 'n_estimators': 727, 'max_depth': 8, 'learning_rate': 0.08609213174337473, 'subsample': 0.8107057409889747, 'colsample_bytree': 0.8763563332327975}
model_a = xgb.XGBRegressor(**params_a)
model_b = xgb.XGBRegressor(**params_b)
model_c = xgb.XGBRegressor(**params_c)

# %%
model_a.fit(x_train_a, y_train_a)
model_b.fit(x_train_b, y_train_b)
model_c.fit(x_train_c, y_train_c)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/peterlawrence/Repos/TDT4173-ML/model_notebooks/XGB_seas_cat_yshift.ipynb Cell 28 line 1
# ----> <a href='vscode-notebook-cell:/Users/peterlawrence/Repos/TDT4173-ML/model_notebooks/XGB_seas_cat_yshift.ipynb#X55sZmlsZQ%3D%3D?line=0'>1</a> model_a.fit(x_train_a, y_train_a)
#       <a href='vscode-notebook-cell:/Users/peterlawrence/Repos/TDT4173-ML/model_notebooks/XGB_seas_cat_yshift.ipynb#X55sZmlsZQ%3D%3D?line=1'>2</a> model_b.fit(x_train_b, y_train_b)
#       <a href='vscode-notebook-cell:/Users/peterlawrence/Repos/TDT4173-ML/model_notebooks/XGB_seas_cat_yshift.ipynb#X55sZmlsZQ%3D%3D?line=2'>3</a> model_c.fit(x_train_c, y_train_c)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py:1086, in XGBModel.fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1075     obj = None
#    1077 (
#    1078     model,
#    1079     metric,
#    (...)
#    1084     xgb_model, eval_metric, params, early_stopping_rounds, callbacks
#    1085 )
# -> 1086 self._Booster = train(
#    1087     params,
#    1088     train_dmatrix,
#    1089     self.get_num_boosting_rounds(),
#    1090     evals=evals,
#    1091     early_stopping_rounds=early_stopping_rounds,
#    1092     evals_result=evals_result,
#    1093     obj=obj,
#    1094     custom_metric=metric,
#    1095     verbose_eval=verbose,
#    1096     xgb_model=model,
#    1097     callbacks=callbacks,
#    1098 )
#    1100 self._set_evaluation_result(evals_result)
#    1101 return self
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/training.py:181, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     179 if cb_container.before_iteration(bst, i, dtrain, evals):
#     180     break
# --> 181 bst.update(dtrain, i, obj)
#     182 if cb_container.after_iteration(bst, i, dtrain, evals):
#     183     break
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py:2050, in Booster.update(self, dtrain, iteration, fobj)
#    2046 self._assign_dmatrix_features(dtrain)
#    2048 if fobj is None:
#    2049     _check_call(
# -> 2050         _LIB.XGBoosterUpdateOneIter(
#    2051             self.handle, ctypes.c_int(iteration), dtrain.handle
#    2052         )
#    2053     )
#    2054 else:
#    2055     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:

# %% [markdown]
# # Make predictions

# %%
model_a.fit(X_train[0], Y_train[0])
model_b.fit(X_train[1], Y_train[1])
model_c.fit(X_train[2], Y_train[2])
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8763563332327975, device=None,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.08609213174337473, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=8, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=727, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %%
# Do some more stuff
y_pred_a = model_a.predict(X_frames_test[0])
y_pred_b = model_b.predict(X_frames_test[1])
y_pred_c = model_c.predict(X_frames_test[2])

# %% [markdown]
# # Evaluate prediction

# %%
# Evaluate the model based on the validation data

mse_a = mean_squared_error(y_val_a, model_a.predict(x_val_a))
print("MSE for A: ", mse_a)
mse_b = mean_squared_error(y_val_b, model_b.predict(x_val_b))
print("MSE for B: ", mse_b)
mse_c = mean_squared_error(y_val_c, model_c.predict(x_val_c))
print("MSE for C: ", mse_c)
print("Mean MSE: ", (mse_a + mse_b + mse_c) / 3)

# Evaluate the predictions

score_a = model_a.score(x_val_a, y_val_a)
score_b = model_b.score(x_val_b, y_val_b)
score_c = model_c.score(x_val_c, y_val_c)

print("Score A: ", score_a)
print("Score B: ", score_b)
print("Score C: ", score_c)
print('')

# Get feature importance scores
models = [(model_a, 'A'), (model_b, 'B'), (model_c, 'C')]
for model in models:

    feature_importance_scores = model[0].feature_importances_

# Create a DataFrame to associate features with their importance scores
    feature_importance_df1 = pd.DataFrame({'Feature': x_train_a.columns, 'Importance': feature_importance_scores})

# Sort features by importance in descending order
    feature_importance_df1 = feature_importance_df1.sort_values(by='Importance', ascending=False)

# Print or visualize the feature importance scores
    
    print(f'Model {model[1]}')
    print(feature_importance_df1.head(10))
    print('')

# %% [markdown]
# # Create submission

# %%
y_pred = np.concatenate((y_pred_a, y_pred_b, y_pred_c), axis=0)

# %%
y_test_pred = y_pred

test = pd.read_csv('../data/test.csv')
test['prediction'] = y_test_pred
sample_submission = pd.read_csv('../data/sample_submission.csv')
submission = sample_submission[['id']].merge(test[['id', 'prediction']], on='id', how='left')
submission.to_csv('submission_xg_y.csv', index=False)
